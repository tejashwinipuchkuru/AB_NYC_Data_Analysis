# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Style for better looking plots
sns.set_style("whitegrid")

# %%
df = pd.read_csv("../data/AB_NYC_Cleaned.csv")

# %%
df.head()
# Out:
#                    id                                               name  \
# 0             1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1            45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2  971353993633883038  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3             3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4            40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
#
#      host_id           host_name neighbourhood_group       neighbourhood  \
# 0    7130382              Walter            Brooklyn        Clinton Hill
# 1   51501835            Jeniffer           Manhattan      Hell's Kitchen
# 2  528871354              Joshua           Manhattan             Chelsea
# 3   19902271  John And Catherine           Manhattan  Washington Heights
# 4   61391963      Stay With Vibe           Manhattan         Murray Hill
#
#     latitude  longitude        room_type  price  ...  last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20758 entries, 0 to 20757
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20758 non-null  int64
#  1   name                            20758 non-null  object
#  2   host_id                         20758 non-null  int64
#  3   host_name                       20758 non-null  object
#  4   neighbourhood_group             20758 non-null  object
#  5   neighbourhood                   20758 non-null  object
#  6   latitude                        20758 non-null  float64
#  7   longitude                       20758 non-null  float64
#  8   room_type                       20758 non-null  object
#  9   price                           20758 non-null  int64
#  10  minimum_nights                  20758 non-null  int64
#  11  number_of_reviews               20758 non-null  int64
# ...

# %%
sorted(df["bedrooms"].unique())
# Out:
# [np.float64(1.0),
#  np.float64(1.4319273610304597),
#  np.float64(2.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(5.0),
#  np.float64(6.0),
#  np.float64(7.0),
#  np.float64(8.0),
#  np.float64(9.0),
#  np.float64(14.0),
#  np.float64(15.0)]

# %%
df[df["bedrooms"] % 1 != 0]
# Out:
#                        id                                               name  \
# 4                40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# 6                45457047  Rental unit in New York · ★4.33 · Studio · 1 b...
# 11               22066430  Rental unit in Brooklyn · ★4.71 · Studio · 1 b...
# 15               29923599  Serviced apartment in New York City · Studio ·...
# 43     881361770950607277  Home in Queens · ★4.67 · Studio · 3 beds · 1 s...
# ...                   ...                                                ...
# 20728            51195659  Rental unit in New York · Studio · 1 bed · 1 bath
# 20732  807933093709359091  Rental unit in New York · ★5.0 · Studio · 1 be...
# 20736  570243211438142391  Rental unit in New York · ★4.67 · Studio · 1 b...
# 20738            27454904  Rental unit in New York · ★4.86 · Studio · 2 b...
# 20748            50361433  Rental unit in New York · ★4.94 · Studio · 1 b...
#
# ...

# %%
df["bedrooms"].value_counts().sort_index()
# Out:
# bedrooms
# 1.000000     13439
# 1.431927      1815
# 2.000000      3602
# 3.000000      1394
# 4.000000       345
# 5.000000       112
# 6.000000        29
# 7.000000         9
# 8.000000         5
# 9.000000         6
# 14.000000        1
# 15.000000        1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  2.075800e+04  2.075800e+04  20758.000000  20758.000000   20758.000000
# mean   3.034044e+17  1.749316e+08     40.726798    -73.939161     187.776616
# std    3.901216e+17  1.725541e+08      0.060294      0.061403    1022.797208
# min    2.595000e+03  1.678000e+03     40.500314    -74.249840      10.000000
# 25%    2.708808e+07  2.041738e+07     40.684150    -73.980710      80.000000
# 50%    4.993003e+07  1.087271e+08     40.722820    -73.949587     125.000000
# 75%    7.216019e+17  3.144102e+08     40.763098    -73.917460     199.000000
# max    1.054376e+18  5.504035e+08     40.911147    -73.713650  100000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20758.000000       20758.000000       20758.000000
# mean        28.558435          42.642596           1.257910
# std         33.536518          73.561654           1.904661
# ...

# %%
df.describe(include='object')
# Out:
#                                                      name host_name  \
# count                                               20758     20758
# unique                                               9836      5815
# top     Rental unit in New York · 1 bedroom · 1 bed · ...  Jeniffer
# freq                                                  409       184
#
#        neighbourhood_group       neighbourhood        room_type last_review  \
# count                20758               20758            20758       20758
# unique                   5                 221                4        1878
# top              Manhattan  Bedford-Stuyvesant  Entire home/apt  04-09-2023
# freq                  8038                1586            11549         326
#
#            license
# count        20758
# unique         879
# top     No License
# freq         17569

# %%
df.describe(include='all')
# Out:
#                   id                                               name  \
# count   2.075800e+04                                              20758
# unique           NaN                                               9836
# top              NaN  Rental unit in New York · 1 bedroom · 1 bed · ...
# freq             NaN                                                409
# mean    3.034044e+17                                                NaN
# std     3.901216e+17                                                NaN
# min     2.595000e+03                                                NaN
# 25%     2.708808e+07                                                NaN
# 50%     4.993003e+07                                                NaN
# 75%     7.216019e+17                                                NaN
# max     1.054376e+18                                                NaN
#
#              host_id host_name neighbourhood_group       neighbourhood  \
# ...

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='room_type', data=df)

plt.title("Distribution of Room Types")
plt.xlabel("Room Type")
plt.ylabel("Number of Listings")
plt.show()

# %% [markdown]
# Entire homes/apartments constitute the majority of Airbnb listings, indicating that guests generally prefer private accommodations over shared spaces

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["price"], bins=40)

plt.title("Distribution of Listing Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Most Airbnb listings are concentrated in the lower price range, while a small number of premium listings create a right-skewed distribution.

# %%
top10 = df["neighbourhood"].value_counts().head(10)

plt.figure(figsize=(12,5))
sns.barplot(x=top10.index, y=top10.values)

plt.xticks(rotation=45)
plt.title("Top 10 Neighborhoods by Number of Listings")
plt.xlabel("Neighborhood")
plt.ylabel("Listings")
plt.show()

# %% [markdown]
# A small number of neighborhoods contribute a large share of Airbnb listings, indicating higher hosting activity in these locations

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='room_type', y='price', data=df)

plt.title("Price Distribution by Room Type")
plt.xlabel("Room Type")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# Entire homes generally have higher prices than private or shared rooms, reflecting greater space and privacy.

# %%
plt.figure(figsize=(10,8))

numeric_df = df.select_dtypes(include=['number'])

sns.heatmap(numeric_df.corr(),
            annot=True,
            cmap='coolwarm',
            fmt=".2f")

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Most numerical features show weak correlations, suggesting that Airbnb pricing is influenced by multiple factors rather than a single variable.

# %% [markdown]
# ## 🔍 Key Insights
#
# - The dataset was successfully cleaned by handling missing values, removing duplicate records, and correcting data inconsistencies.
# - Exploratory Data Analysis (EDA) helped identify important patterns, trends, and relationships within the dataset.
# - The visualizations provided a clear understanding of the distribution of variables and highlighted significant characteristics of the data.
# - Correlation analysis revealed the strength of relationships between numerical features, supporting deeper data exploration.
# - The analysis transformed raw data into meaningful insights that can assist in data-driven decision-making.

# %% [markdown]
# ## Conclusion
#
# The exploratory data analysis revealed several meaningful patterns within the Airbnb NYC dataset.
#
# Most listings belong to the "Entire Home/Apartment" category, indicating strong demand for private accommodations. The price distribution is positively skewed, with the majority of listings being affordable while only a small percentage are premium-priced. Certain neighborhoods have a significantly higher concentration of listings, suggesting that Airbnb activity is not evenly distributed across New York City.
#
# The correlation analysis shows that no single numerical feature strongly determines listing price, indicating that pricing depends on multiple factors such as location, room type, amenities, and host characteristics.
#
# Overall, the cleaned dataset is well-prepared for advanced analytics, dashboard development, and predictive machine learning applications.
